# %%
from __future__ import unicode_literals, print_function
import spacy
import en_core_web_sm
import en_core_web_md
# import en_core_web_lg
import random
from pathlib import Path
from spacy.util import minibatch, compounding
import tarfile
import xml.etree.ElementTree as ET
import os
from pandas import ExcelWriter
import pandas as pd
from sklearn.model_selection import train_test_split
import timeit
from spacy.gold import GoldParse
from spacy.scorer import Scorer
from spacy.util import decaying

# %%
def get_batches(train_data, model_type):
    max_batch_sizes = {"tagger": 32, "parser": 16, "ner": 16, "textcat": 64}
    max_batch_size = max_batch_sizes[model_type]
    if len(train_data) < 1000:
        max_batch_size /= 2
    if len(train_data) < 500:
        max_batch_size /= 2
    batch_size = compounding(1, max_batch_size, 1.001)
    batches = minibatch(train_data, size=batch_size)
    return batches
def transformName(orginalData = None):
    texts = [text for text in orginalData['text']]
    transformTags = []
    for tags in orginalData['tags']:
        entity = {'entities': []}
        for tag in eval(tags):
            if tag['TYPE'] == 'DOCTOR' or tag['TYPE'] == 'PATIENT':
                entity['entities'].append((int(tag['start']), int(tag['end']), 'NAME'))
        transformTags.append(entity)
    transformedTrain = list(zip(texts, transformTags))
    return transformedTrain
def findAllEntityTransform(data = None):
    uniqueTag = set()
    for (_, tags) in data:
        for tag in tags['entities']:
            uniqueTag.add(tag[2])
    return uniqueTag
def findOneEntity(data = None, entType = None):
    for tags in data['tags']:
        for tag in eval(tags):
            if tag['TYPE'] == entType:
                print(tag)
def evaluate(ner_model, examples, n_iter):
    stats = ['ents_f']
    scorer = Scorer() 
    for input_, annot in examples:
        try:
            doc_gold_text = ner_model.make_doc(input_) #the raw text
            gold = GoldParse(doc_gold_text, entities=annot['entities']) # combine the raw text with corrected id
            pred_value = ner_model(input_) # a doc object, which contains the predicted entity
            scorer.score(pred_value, gold) # calculate the accuracy
        except:
            textWithProblem.append((input_, annot))
    return {n_iter: scorer.scores[k] for k in stats} # accumulate all the documents

# find all entity type in the original data
def findAllEntity(data = None):
    uniqueTag = set()
    [[uniqueTag.add(tag['TYPE']) for tag in eval(tags)] for tags in data['tags']]
    return uniqueTag

# %%
def main(model=None, n_iter=3, output_dir=None):
    """Set up the pipeline and entity recognizer, and train the new entity."""
    random.seed(0)
    if model is not None:
        nlp = spacy.load(model) # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")
    # Add entity recognizer to model if it's not in the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner)
    # otherwise, get it, so we can add labels to it
    else:
        ner = nlp.get_pipe("ner")
    for LABEL in uniqueTag:
        ner.add_label(LABEL)  # add new entity label to entity recognizer
    # Adding extraneous labels shouldn't mess anything up
#     ner.add_label("VEGETABLE")
    if model is None:
        optimizer = nlp.begin_training()
    else:
        optimizer = nlp.resume_training()
    move_names = list(ner.move_names)
    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    dropout = decaying(0.6, 0.2, 1e-4)
    batches = get_batches(train_data=TRAIN_DATA, model_type='ner')
    with nlp.disable_pipes(*other_pipes):  # only train NER
#         sizes = compounding(4, 32, 1.001)
        # batch up the examples using spaCy's minibatch
        for itn in range(n_iter):            
            if itn%3 == 0:
                random.shuffle(TRAIN_DATA)               
                losses = {}
                for batch in batches:
                    texts, annotations = zip(*batch)
                    try:
                        nlp.update(texts, annotations, sgd=optimizer, drop=next(dropout), losses=losses)
                    except:
                        textWithProblem.append(texts)
                        pass
                print("Losses", losses)
                if output_dir + str(itn) is not None:
                    output_dir = Path(output_dir)
                    if not output_dir.exists():
                        output_dir.mkdir()
            #         nlp.meta["name"] = new_model_name  # rename model
                    nlp.to_disk(output_dir)
                    f1Train.append(evaluate(nlp, TRAIN_DATA, n_iter = itn))
                    f1Test.append(evaluate(nlp, TEST_DATA, n_iter = itn))
                    print("Saved model to", output_dir)
            else:
                random.shuffle(TRAIN_DATA)
                losses = {}
                for batch in batches:
                    texts, annotations = zip(*batch)
                    try:
                        nlp.update(texts, annotations, sgd=optimizer, drop=next(dropout), losses=losses)
                    except:
                        textWithProblem.append(texts)
                        pass
                f1Train.append(evaluate(nlp, TRAIN_DATA, n_iter = itn))
                f1Test.append(evaluate(nlp, TEST_DATA, n_iter = itn))
                print("Losses", losses)

    # save model to output directory
    if output_dir + str(n_itr) is not None:
        output_dir = Path(output_dir + str(n_itr))
        if not output_dir.exists():
            output_dir.mkdir()
#         nlp.meta["name"] = new_model_name  # rename model
        nlp.to_disk(output_dir)
        f1Train.append(evaluate(nlp, TRAIN_DATA, n_iter = n_iter))
        f1Test.append(evaluate(nlp, TEST_DATA, n_iter = n_iter))
        print("Saved model to", output_dir)

# %%
f1Train = []
f1Test = []
df = pd.read_excel('./PythonExport.xlsx')
df_2006Train = pd.read_excel('./i2b2-2006Train.xlsx')
df_2006Test = pd.read_excel('./i2b2-2006Test.xlsx')
df = pd.concat([df, df_2006Test, df_2006Train], axis = 0)
train, test = train_test_split(df, test_size=0.1, random_state = 42)
transformedTrainDate = transformDate(train)
transformedTestDate = transformDate(test)
uniqueTag = findAllEntityTransform(transformedTrainDate)
TRAIN_DATA = transformedTrainDate
TEST_DATA = transformedTestDate
textWithProblem = []

# %%
df = pd.read_excel('./PythonExport.xlsx')
df_2006Train = pd.read_excel('./i2b2-2006Train.xlsx')
df_2006Test = pd.read_excel('./i2b2-2006Test.xlsx')

# %%
len(df)
# Out:
# 790

# %%
len(df_2006Train)
# Out:
# 668

# %%
len(df_2006Test)
# Out:
# 220

# %%
findOneEntity(data = df_2006Train, entType='PATIENT')
# Out:
# {'start': '275', 'end': '280', 'text': 'Blind', 'TYPE': 'PATIENT'}
# {'start': '242', 'end': '263', 'text': 'GIRRESNET , DIEDREO A', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '168', 'text': 'LYSSFUST , NY', 'TYPE': 'PATIENT'}
# {'start': '132', 'end': '149', 'text': 'GLASS , NELLE KKE', 'TYPE': 'PATIENT'}
# {'start': '1036', 'end': '1041', 'text': 'Glass', 'TYPE': 'PATIENT'}
# {'start': '1394', 'end': '1399', 'text': 'Glass', 'TYPE': 'PATIENT'}
# {'start': '1394', 'end': '1399', 'text': 'Glass', 'TYPE': 'PATIENT'}
# {'start': '193', 'end': '215', 'text': 'MERVBENWIERST , BIE S.', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '154', 'text': 'HUHTLAND , CIE', 'TYPE': 'PATIENT'}
# {'start': '280', 'end': '294', 'text': 'HUHTLAND , CIE', 'TYPE': 'PATIENT'}
# {'start': '422', 'end': '435', 'text': 'Tlandpiernshi', 'TYPE': 'PATIENT'}
# {'start': '1282', 'end': '1295', 'text': 'Tlandpiernshi', 'TYPE': 'PATIENT'}
# {'start': '2441', 'end': '2454', 'text': 'Tlandpiernshi', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '156', 'text': 'LONGSWALD , NAER', 'TYPE': 'PATIENT'}
# {'start': '282', 'end': '298', 'text': 'LONGSWALD , NAER', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '146', 'text': 'KOTE , CIHA L', 'TYPE': 'PATIENT'}
# {'start': '180', 'end': '199', 'text': 'KAASPARD , NACEN D.', 'TYPE': 'PATIENT'}
# {'start': '132', 'end': '154', 'text': 'FONGFYFENOUN , CHELEDA', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '150', 'text': 'STIRESPARD , ACEE', 'TYPE': 'PATIENT'}
# {'start': '1179', 'end': '1185', 'text': 'Counts', 'TYPE': 'PATIENT'}
# {'start': '2947', 'end': '2952', 'text': 'Gross', 'TYPE': 'PATIENT'}
# {'start': '3447', 'end': '3464', 'text': 'Inemacistin Gross', 'TYPE': 'PATIENT'}
# {'start': '592', 'end': '598', 'text': 'Little', 'TYPE': 'PATIENT'}
# {'start': '3509', 'end': '3518', 'text': 'Fyfeshuff', 'TYPE': 'PATIENT'}
# {'start': '684', 'end': '689', 'text': 'Breun', 'TYPE': 'PATIENT'}
# {'start': '6659', 'end': '6664', 'text': 'Breun', 'TYPE': 'PATIENT'}
# {'start': '6659', 'end': '6664', 'text': 'Breun', 'TYPE': 'PATIENT'}
# {'start': '739', 'end': '748', 'text': 'Pandeprob', 'TYPE': 'PATIENT'}
# {'start': '441', 'end': '449', 'text': 'Nertland', 'TYPE': 'PATIENT'}
# {'start': '314', 'end': '320', 'text': 'Larsen', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '146', 'text': 'JEM , ON', 'TYPE': 'PATIENT'}
# {'start': '272', 'end': '280', 'text': 'JEM , ON', 'TYPE': 'PATIENT'}
# {'start': '134', 'end': '147', 'text': 'STERPSAP , NY', 'TYPE': 'PATIENT'}
# {'start': '722', 'end': '730', 'text': 'STERPSAP', 'TYPE': 'PATIENT'}
# {'start': '2899', 'end': '2907', 'text': 'STERPSAP', 'TYPE': 'PATIENT'}
# {'start': '2899', 'end': '2907', 'text': 'STERPSAP', 'TYPE': 'PATIENT'}
# {'start': '128', 'end': '145', 'text': 'JESCOBEJESC , SON', 'TYPE': 'PATIENT'}
# {'start': '129', 'end': '142', 'text': 'RULE , CHASHA', 'TYPE': 'PATIENT'}
# {'start': '227', 'end': '231', 'text': 'Rule', 'TYPE': 'PATIENT'}
# {'start': '227', 'end': '231', 'text': 'Rule', 'TYPE': 'PATIENT'}
# {'start': '190', 'end': '203', 'text': 'Saujule Study', 'TYPE': 'PATIENT'}
# {'start': '129', 'end': '148', 'text': 'BEATHEMARES , KELAN', 'TYPE': 'PATIENT'}
# {'start': '163', 'end': '183', 'text': 'TLANDSTREU , SONMYRN', 'TYPE': 'PATIENT'}
# {'start': '130', 'end': '152', 'text': 'PANDEPROB , ORINNEREEN', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '198', 'text': 'KOTE , LYFRANKLAPALM', 'TYPE': 'PATIENT'}
# {'start': '129', 'end': '162', 'text': 'SIAYUDE LARI AGACHJESCTLANDSTONGE', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '155', 'text': 'GLOTZLINKE , ODRA', 'TYPE': 'PATIENT'}
# {'start': '281', 'end': '298', 'text': 'GLOTZLINKE , ODRA', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '158', 'text': 'KAYSLANCE , ICEROYLN', 'TYPE': 'PATIENT'}
# {'start': '284', 'end': '304', 'text': 'KAYSLANCE , ICEROYLN', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '145', 'text': 'CARD , I', 'TYPE': 'PATIENT'}
# {'start': '271', 'end': '279', 'text': 'CARD , I', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '153', 'text': 'JUNK , KACHOLERA', 'TYPE': 'PATIENT'}
# {'start': '279', 'end': '295', 'text': 'JUNK , KACHOLERA', 'TYPE': 'PATIENT'}
# {'start': '130', 'end': '151', 'text': 'WIERSTUPH , NORNAME H', 'TYPE': 'PATIENT'}
# {'start': '128', 'end': '144', 'text': 'NEATHE , SAUJULE', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '156', 'text': 'FREIREKOTE , SONYLA', 'TYPE': 'PATIENT'}
# {'start': '282', 'end': '301', 'text': 'FREIREKOTE , SONYLA', 'TYPE': 'PATIENT'}
# {'start': '182', 'end': '188', 'text': 'Tennis', 'TYPE': 'PATIENT'}
# {'start': '616', 'end': '620', 'text': 'List', 'TYPE': 'PATIENT'}
# {'start': '204', 'end': '220', 'text': 'NERSLET , BERISS', 'TYPE': 'PATIENT'}
# {'start': '149', 'end': '165', 'text': 'JUNK , KACHOLERA', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '161', 'text': 'STRAPEFREIRE , VATALY C', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '160', 'text': 'BELBBREUN , VICKANT M', 'TYPE': 'PATIENT'}
# {'start': '336', 'end': '350', 'text': 'Breutzfarstxei', 'TYPE': 'PATIENT'}
# {'start': '336', 'end': '350', 'text': 'Breutzfarstxei', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '162', 'text': 'BEATHEMARES , KELAN', 'TYPE': 'PATIENT'}
# {'start': '986', 'end': '994', 'text': 'Kotereef', 'TYPE': 'PATIENT'}
# {'start': '149', 'end': '166', 'text': 'BOEHKOTE , SONA S', 'TYPE': 'PATIENT'}
# {'start': '4232', 'end': '4242', 'text': 'Fleetheesc', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '176', 'text': 'HOUGHTJESCSLEM , RIESHINJIN R', 'TYPE': 'PATIENT'}
# {'start': '148', 'end': '162', 'text': 'AKOTE , RALPRI', 'TYPE': 'PATIENT'}
# {'start': '288', 'end': '302', 'text': 'AKOTE , RALPRI', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '161', 'text': 'PRUESSCHIRD , RIIE', 'TYPE': 'PATIENT'}
# {'start': '141', 'end': '160', 'text': 'RALNMOTTEFUH , AEEN', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '168', 'text': 'JEDL , SHONDLONDNAALE', 'TYPE': 'PATIENT'}
# {'start': '294', 'end': '315', 'text': 'JEDL , SHONDLONDNAALE', 'TYPE': 'PATIENT'}
# {'start': '149', 'end': '173', 'text': 'FORRESNEIGH , LINDNARI V', 'TYPE': 'PATIENT'}
# {'start': '3262', 'end': '3273', 'text': 'Forresneigh', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '208', 'text': 'ZETZFYFEDALEMNONJESC , RYSTA A', 'TYPE': 'PATIENT'}
# {'start': '1056', 'end': '1076', 'text': 'Zetzfyfedalemnonjesc', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '160', 'text': 'RATHELIFE , TIEANAKI B', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '152', 'text': 'PA , THA', 'TYPE': 'PATIENT'}
# {'start': '456', 'end': '458', 'text': 'Pa', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '169', 'text': 'PANDEPROB , ORINNEREEN', 'TYPE': 'PATIENT'}
# {'start': '295', 'end': '317', 'text': 'PANDEPROB , ORINNEREEN', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '146', 'text': 'ELMS , DAIE L', 'TYPE': 'PATIENT'}
# {'start': '676', 'end': '685', 'text': 'Daie Elms', 'TYPE': 'PATIENT'}
# {'start': '681', 'end': '685', 'text': 'Elms', 'TYPE': 'PATIENT'}
# {'start': '4170', 'end': '4174', 'text': 'Elms', 'TYPE': 'PATIENT'}
# {'start': '312', 'end': '324', 'text': 'Kotekoorsner', 'TYPE': 'PATIENT'}
# {'start': '2739', 'end': '2751', 'text': 'Kotekoorsner', 'TYPE': 'PATIENT'}
# {'start': '200', 'end': '203', 'text': 'Ere', 'TYPE': 'PATIENT'}
# {'start': '755', 'end': '759', 'text': 'Mass', 'TYPE': 'PATIENT'}
# {'start': '881', 'end': '885', 'text': 'Mass', 'TYPE': 'PATIENT'}
# {'start': '6539', 'end': '6543', 'text': 'Mass', 'TYPE': 'PATIENT'}
# {'start': '7216', 'end': '7220', 'text': 'Mass', 'TYPE': 'PATIENT'}
# {'start': '7683', 'end': '7687', 'text': 'Mass', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '172', 'text': 'SIEWMARV , LEOA', 'TYPE': 'PATIENT'}
# {'start': '524', 'end': '537', 'text': 'Leoa Siewmarv', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '179', 'text': 'LENKPRUSKIHKOOGLEKIH , NIEKERO C', 'TYPE': 'PATIENT'}
# {'start': '500', 'end': '520', 'text': 'Lenkpruskihkooglekih', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '165', 'text': 'GURNEPASCCAUGH , NIA L', 'TYPE': 'PATIENT'}
# {'start': '142', 'end': '162', 'text': 'ELKSCHIRD , EBERTA R', 'TYPE': 'PATIENT'}
# {'start': '192', 'end': '204', 'text': 'COND , TOILD', 'TYPE': 'PATIENT'}
# {'start': '158', 'end': '178', 'text': 'HIBBSLIRES , LOJOA M', 'TYPE': 'PATIENT'}
# {'start': '2407', 'end': '2417', 'text': 'Hibbslires', 'TYPE': 'PATIENT'}
# {'start': '431', 'end': '435', 'text': 'Cast', 'TYPE': 'PATIENT'}
# {'start': '183', 'end': '195', 'text': 'REEF , SANTA', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '174', 'text': 'KOTELEEBDILS , TOZA S', 'TYPE': 'PATIENT'}
# {'start': '6574', 'end': '6586', 'text': 'Koteleebdils', 'TYPE': 'PATIENT'}
# {'start': '357', 'end': '361', 'text': 'Noun', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '168', 'text': 'FALMDREPSGREND , LINE', 'TYPE': 'PATIENT'}
# {'start': '294', 'end': '315', 'text': 'FALMDREPSGREND , LINE', 'TYPE': 'PATIENT'}
# {'start': '195', 'end': '199', 'text': 'Rule', 'TYPE': 'PATIENT'}
# {'start': '6462', 'end': '6466', 'text': 'Rule', 'TYPE': 'PATIENT'}
# {'start': '182', 'end': '204', 'text': 'MESQUOWNFETH , LIBRENT', 'TYPE': 'PATIENT'}
# {'start': '8674', 'end': '8679', 'text': 'Hauth', 'TYPE': 'PATIENT'}
# {'start': '8674', 'end': '8679', 'text': 'Hauth', 'TYPE': 'PATIENT'}
# {'start': '287', 'end': '292', 'text': 'Stone', 'TYPE': 'PATIENT'}
# {'start': '4189', 'end': '4194', 'text': 'Stone', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '171', 'text': 'TLANDSHUFFBREUTZLEESE , EZEJO N', 'TYPE': 'PATIENT'}
# {'start': '397', 'end': '399', 'text': 'Po', 'TYPE': 'PATIENT'}
# {'start': '397', 'end': '399', 'text': 'Po', 'TYPE': 'PATIENT'}
# {'start': '141', 'end': '155', 'text': 'SHUFF , RONHUM', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '197', 'text': 'CALL , GRANRIVERN S', 'TYPE': 'PATIENT'}
# {'start': '759', 'end': '774', 'text': 'Granrivern Call', 'TYPE': 'PATIENT'}
# {'start': '338', 'end': '344', 'text': 'Marker', 'TYPE': 'PATIENT'}
# {'start': '5073', 'end': '5079', 'text': 'Marker', 'TYPE': 'PATIENT'}
# {'start': '5345', 'end': '5351', 'text': 'Marker', 'TYPE': 'PATIENT'}
# {'start': '5345', 'end': '5351', 'text': 'Marker', 'TYPE': 'PATIENT'}
# {'start': '6415', 'end': '6421', 'text': 'Marker', 'TYPE': 'PATIENT'}
# {'start': '152', 'end': '169', 'text': 'LESS , LIESEANALE', 'TYPE': 'PATIENT'}
# {'start': '3905', 'end': '3909', 'text': 'Less', 'TYPE': 'PATIENT'}
# {'start': '3905', 'end': '3909', 'text': 'Less', 'TYPE': 'PATIENT'}
# {'start': '263', 'end': '271', 'text': 'Kotefyfe', 'TYPE': 'PATIENT'}
# {'start': '4895', 'end': '4913', 'text': 'Lyfranklapalm Kote', 'TYPE': 'PATIENT'}
# {'start': '3073', 'end': '3078', 'text': 'Sligh', 'TYPE': 'PATIENT'}
# {'start': '209', 'end': '236', 'text': 'BAINHEAGLESAPJESC , ROLORES', 'TYPE': 'PATIENT'}
# {'start': '1789', 'end': '1806', 'text': 'Bainheaglesapjesc', 'TYPE': 'PATIENT'}
# {'start': '150', 'end': '168', 'text': 'VESSELS , TISTIE D', 'TYPE': 'PATIENT'}
# {'start': '564', 'end': '571', 'text': 'Vessels', 'TYPE': 'PATIENT'}
# {'start': '751', 'end': '758', 'text': 'Vessels', 'TYPE': 'PATIENT'}
# {'start': '508', 'end': '513', 'text': 'Shuff', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '185', 'text': 'ZISK , MAPI T', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '158', 'text': 'STERPNEEK , SHAUA M', 'TYPE': 'PATIENT'}
# {'start': '152', 'end': '170', 'text': 'STIRE , BRIETHAN B', 'TYPE': 'PATIENT'}
# {'start': '392', 'end': '397', 'text': 'Stire', 'TYPE': 'PATIENT'}
# {'start': '4056', 'end': '4061', 'text': 'Stire', 'TYPE': 'PATIENT'}
# {'start': '5634', 'end': '5639', 'text': 'Stire', 'TYPE': 'PATIENT'}
# {'start': '255', 'end': '275', 'text': 'TLANDSEUSS , CHERE C', 'TYPE': 'PATIENT'}
# {'start': '142', 'end': '164', 'text': 'GARNSTLAND , AUNDNAE C', 'TYPE': 'PATIENT'}
# {'start': '158', 'end': '186', 'text': 'NEIGHSTERPTIK , ANELLERICKAT', 'TYPE': 'PATIENT'}
# {'start': '184', 'end': '188', 'text': 'Less', 'TYPE': 'PATIENT'}
# {'start': '381', 'end': '385', 'text': 'Less', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '163', 'text': 'SLEMNEAVKOTE , PAUCI', 'TYPE': 'PATIENT'}
# {'start': '618', 'end': '619', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '1331', 'end': '1332', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '2900', 'end': '2901', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '3944', 'end': '3945', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '4185', 'end': '4186', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '4678', 'end': '4679', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '4772', 'end': '4773', 'text': 'A', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '151', 'text': 'URKE , AMA L', 'TYPE': 'PATIENT'}
# {'start': '148', 'end': '160', 'text': 'BURCE , LLNO', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '298', 'text': 'BURCE , LLNO', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '175', 'text': 'CHESNECHESNEWIERST , AMESAND', 'TYPE': 'PATIENT'}
# {'start': '301', 'end': '329', 'text': 'CHESNECHESNEWIERST , AMESAND', 'TYPE': 'PATIENT'}
# {'start': '191', 'end': '201', 'text': 'Cean Leach', 'TYPE': 'PATIENT'}
# {'start': '389', 'end': '394', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '1961', 'end': '1966', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '6448', 'end': '6453', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '8063', 'end': '8068', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '8063', 'end': '8068', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '8063', 'end': '8068', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '8063', 'end': '8068', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '12692', 'end': '12697', 'text': 'Leach', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '165', 'text': 'FYFEUARDFEL , TADE', 'TYPE': 'PATIENT'}
# {'start': '291', 'end': '309', 'text': 'FYFEUARDFEL , TADE', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '175', 'text': 'AKOTEBONTKAYS , JUANQUINTLEO', 'TYPE': 'PATIENT'}
# {'start': '301', 'end': '329', 'text': 'AKOTEBONTKAYS , JUANQUINTLEO', 'TYPE': 'PATIENT'}
# {'start': '826', 'end': '848', 'text': 'Nakoloyd Knutzxelljesc', 'TYPE': 'PATIENT'}
# {'start': '4856', 'end': '4869', 'text': 'Knutzxelljesc', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '160', 'text': 'BRITTSJESC , DENET R', 'TYPE': 'PATIENT'}
# {'start': '174', 'end': '194', 'text': 'KAYSPLASS , SHALYO M', 'TYPE': 'PATIENT'}
# {'start': '533', 'end': '549', 'text': 'Shalyo Kaysplass', 'TYPE': 'PATIENT'}
# {'start': '540', 'end': '549', 'text': 'Kaysplass', 'TYPE': 'PATIENT'}
# {'start': '1936', 'end': '1952', 'text': 'Shalyo Kaysplass', 'TYPE': 'PATIENT'}
# {'start': '152', 'end': '166', 'text': 'CLOZ , NBURT R', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '164', 'text': 'SHUFFNEIGH , FORDRY L', 'TYPE': 'PATIENT'}
# {'start': '678', 'end': '687', 'text': 'Prehekote', 'TYPE': 'PATIENT'}
# {'start': '6696', 'end': '6705', 'text': 'Prehekote', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '159', 'text': 'RHALTDEALBBREUTZ , STA', 'TYPE': 'PATIENT'}
# {'start': '285', 'end': '307', 'text': 'RHALTDEALBBREUTZ , STA', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '168', 'text': 'FINGER , ASHA', 'TYPE': 'PATIENT'}
# {'start': '4269', 'end': '4275', 'text': 'Finger', 'TYPE': 'PATIENT'}
# {'start': '2399', 'end': '2412', 'text': 'Drinkotescarv', 'TYPE': 'PATIENT'}
# {'start': '142', 'end': '156', 'text': 'DRICKKIH , NEY', 'TYPE': 'PATIENT'}
# {'start': '160', 'end': '171', 'text': 'CA , NISANT', 'TYPE': 'PATIENT'}
# {'start': '350', 'end': '366', 'text': 'Vinktlandfreierm', 'TYPE': 'PATIENT'}
# {'start': '186', 'end': '198', 'text': 'Fyfeguayfalc', 'TYPE': 'PATIENT'}
# {'start': '971', 'end': '983', 'text': 'Fyfeguayfalc', 'TYPE': 'PATIENT'}
# {'start': '2240', 'end': '2262', 'text': 'Ment Fede Motcloffrobe', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '153', 'text': 'SCOBE , RYLALON', 'TYPE': 'PATIENT'}
# {'start': '279', 'end': '294', 'text': 'SCOBE , RYLALON', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '151', 'text': 'SLIGH , ANNEE', 'TYPE': 'PATIENT'}
# {'start': '277', 'end': '290', 'text': 'SLIGH , ANNEE', 'TYPE': 'PATIENT'}
# {'start': '1790', 'end': '1793', 'text': 'ais', 'TYPE': 'PATIENT'}
# {'start': '149', 'end': '165', 'text': 'BATH , JUANARI C', 'TYPE': 'PATIENT'}
# {'start': '795', 'end': '799', 'text': 'Bath', 'TYPE': 'PATIENT'}
# {'start': '130', 'end': '147', 'text': 'FRENDTLAND , NEYE', 'TYPE': 'PATIENT'}
# {'start': '130', 'end': '155', 'text': 'NETSHUFFSCARVTRACE , RIRA', 'TYPE': 'PATIENT'}
# {'start': '130', 'end': '150', 'text': 'KOTE , LYFRANKLAPALM', 'TYPE': 'PATIENT'}
# {'start': '164', 'end': '178', 'text': 'KOTEOBEA , KAY', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '170', 'text': 'WYNDEALB , AUALE', 'TYPE': 'PATIENT'}
# {'start': '135', 'end': '149', 'text': 'LOOSE , BERISS', 'TYPE': 'PATIENT'}
# {'start': '5183', 'end': '5188', 'text': 'Loose', 'TYPE': 'PATIENT'}
# {'start': '130', 'end': '144', 'text': 'GLORENC , NILD', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '153', 'text': 'SLEMNEAVKOTE , PAUCI', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '156', 'text': 'CAPKOTESKOC , KER', 'TYPE': 'PATIENT'}
# {'start': '282', 'end': '299', 'text': 'CAPKOTESKOC , KER', 'TYPE': 'PATIENT'}
# {'start': '175', 'end': '184', 'text': 'GACH , CH', 'TYPE': 'PATIENT'}
# {'start': '1120', 'end': '1124', 'text': 'Gach', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '147', 'text': 'DOSE , LEYRU K', 'TYPE': 'PATIENT'}
# {'start': '642', 'end': '646', 'text': 'Dose', 'TYPE': 'PATIENT'}
# {'start': '141', 'end': '165', 'text': 'MERVBENWIERST , EZOSAN B', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '154', 'text': 'KOTEGLO , IESA', 'TYPE': 'PATIENT'}
# {'start': '280', 'end': '294', 'text': 'KOTEGLO , IESA', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '160', 'text': 'KOTE , LYFRANKLAPALM', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '306', 'text': 'KOTE , LYFRANKLAPALM', 'TYPE': 'PATIENT'}
# {'start': '151', 'end': '173', 'text': 'SUBEJALKTLAND , ALEI R', 'TYPE': 'PATIENT'}
# {'start': '141', 'end': '160', 'text': 'DOUINFREIERM , AEUN', 'TYPE': 'PATIENT'}
# {'start': '287', 'end': '306', 'text': 'DOUINFREIERM , AEUN', 'TYPE': 'PATIENT'}
# {'start': '141', 'end': '158', 'text': 'KOTEFOOKS , DASHA', 'TYPE': 'PATIENT'}
# {'start': '284', 'end': '301', 'text': 'KOTEFOOKS , DASHA', 'TYPE': 'PATIENT'}
# {'start': '7961', 'end': '7963', 'text': 'Po', 'TYPE': 'PATIENT'}
# {'start': '427', 'end': '431', 'text': 'Loss', 'TYPE': 'PATIENT'}
# {'start': '152', 'end': '175', 'text': 'FYFEREOSKOTE , CILLMA M', 'TYPE': 'PATIENT'}
# {'start': '610', 'end': '618', 'text': 'Siehjesc', 'TYPE': 'PATIENT'}
# {'start': '141', 'end': '161', 'text': 'GLEENLAUNT , JACEA E', 'TYPE': 'PATIENT'}
# {'start': '459', 'end': '463', 'text': 'Lyme', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '164', 'text': 'TLANDTHRELKHISSE , LIEIL', 'TYPE': 'PATIENT'}
# {'start': '290', 'end': '314', 'text': 'TLANDTHRELKHISSE , LIEIL', 'TYPE': 'PATIENT'}
# {'start': '134', 'end': '159', 'text': 'SKOLKSCOSTDALE , ENEREU D', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '154', 'text': 'BREUNDAIL , NETFA', 'TYPE': 'PATIENT'}
# {'start': '811', 'end': '815', 'text': 'Kote', 'TYPE': 'PATIENT'}
# {'start': '2313', 'end': '2317', 'text': 'Kote', 'TYPE': 'PATIENT'}
# {'start': '176', 'end': '194', 'text': 'FYFEUARDFEL , TADE', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '147', 'text': 'FACTOR , REBEM', 'TYPE': 'PATIENT'}
# {'start': '660', 'end': '666', 'text': 'Factor', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '157', 'text': 'ELKSBLEAK , YINGJUEY', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '160', 'text': 'KOTE , LYFRANKLAPALM', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '306', 'text': 'KOTE , LYFRANKLAPALM', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '155', 'text': 'NERSLET , BERISS', 'TYPE': 'PATIENT'}
# {'start': '281', 'end': '297', 'text': 'NERSLET , BERISS', 'TYPE': 'PATIENT'}
# {'start': '151', 'end': '172', 'text': 'CHAFFBREUNGLOTZ , ARI', 'TYPE': 'PATIENT'}
# {'start': '552', 'end': '563', 'text': 'Chysfreierm', 'TYPE': 'PATIENT'}
# {'start': '133', 'end': '144', 'text': 'A , REBAY J', 'TYPE': 'PATIENT'}
# {'start': '175', 'end': '193', 'text': 'NERSLET , BERISS D', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '152', 'text': 'STERPMOONE , NY', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '145', 'text': 'KOTE , OA', 'TYPE': 'PATIENT'}
# {'start': '200', 'end': '209', 'text': 'YAW , TAO', 'TYPE': 'PATIENT'}
# {'start': '180', 'end': '201', 'text': 'JESCBULLSSUBE , SHALL', 'TYPE': 'PATIENT'}
# {'start': '181', 'end': '209', 'text': 'MAAGTLANDBELB , CIOLEBOYCENA', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '164', 'text': 'FYFEKOTETHORE , TEMPIPAU T', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '181', 'text': 'XIEACASS BETHCONRI BLOUNT', 'TYPE': 'PATIENT'}
# {'start': '290', 'end': '301', 'text': 'Ri Strength', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '153', 'text': 'CHAFFGIG , LAKI R', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '160', 'text': 'BLEICHYORKSCRUP , RYLA A', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '151', 'text': 'DULDKOTE , EI N', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '161', 'text': 'BEATHEFIGE , NAENOME M', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '164', 'text': 'LINKEKORC , BESSDRIENNE A', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '151', 'text': 'NEEK , MAYTA L', 'TYPE': 'PATIENT'}
# {'start': '931', 'end': '941', 'text': 'Mayta Neek', 'TYPE': 'PATIENT'}
# {'start': '3648', 'end': '3654', 'text': 'Second', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '173', 'text': 'FREIERMLINKENEIGHCAABLINFARST , ANEA', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '161', 'text': 'CLANCEFELJESC , AUACI N', 'TYPE': 'PATIENT'}
# {'start': '185', 'end': '204', 'text': 'HIBBSKOTE , SIALIND', 'TYPE': 'PATIENT'}
# {'start': '1419', 'end': '1428', 'text': 'Hibbskote', 'TYPE': 'PATIENT'}
# {'start': '189', 'end': '219', 'text': 'VANGESKIBEATHETLAND , AJOEAN J', 'TYPE': 'PATIENT'}
# {'start': '468', 'end': '476', 'text': 'Straight', 'TYPE': 'PATIENT'}
# {'start': '682', 'end': '690', 'text': 'Straight', 'TYPE': 'PATIENT'}
# {'start': '682', 'end': '690', 'text': 'Straight', 'TYPE': 'PATIENT'}
# {'start': '1645', 'end': '1653', 'text': 'Straight', 'TYPE': 'PATIENT'}
# {'start': '2610', 'end': '2618', 'text': 'Straight', 'TYPE': 'PATIENT'}
# {'start': '4120', 'end': '4128', 'text': 'Straight', 'TYPE': 'PATIENT'}
# {'start': '324', 'end': '327', 'text': 'Dua', 'TYPE': 'PATIENT'}
# {'start': '4276', 'end': '4279', 'text': 'Dua', 'TYPE': 'PATIENT'}
# {'start': '4276', 'end': '4279', 'text': 'Dua', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '149', 'text': 'LOAN , LYKEY', 'TYPE': 'PATIENT'}
# {'start': '142', 'end': '165', 'text': 'TRICHEPRAKEJESC , BETLA', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '151', 'text': 'JEMSKOP , COT', 'TYPE': 'PATIENT'}
# {'start': '419', 'end': '433', 'text': 'Chesnedaizbelb', 'TYPE': 'PATIENT'}
# {'start': '266', 'end': '277', 'text': 'Jae Rocgelt', 'TYPE': 'PATIENT'}
# {'start': '1110', 'end': '1117', 'text': 'Rocgelt', 'TYPE': 'PATIENT'}
# {'start': '1497', 'end': '1504', 'text': 'Rocgelt', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '169', 'text': 'GUYNLORDSMANTDOUET , ARYRISTE T', 'TYPE': 'PATIENT'}
# {'start': '2769', 'end': '2787', 'text': 'On Elksfalcbainkih', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '155', 'text': 'WALKING , ODAR D', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '452', 'end': '459', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '4189', 'end': '4196', 'text': 'Walking', 'TYPE': 'PATIENT'}
# {'start': '180', 'end': '192', 'text': 'SUCH , NORLI', 'TYPE': 'PATIENT'}
# {'start': '2567', 'end': '2571', 'text': 'Such', 'TYPE': 'PATIENT'}
# {'start': '3028', 'end': '3032', 'text': 'Such', 'TYPE': 'PATIENT'}
# {'start': '3028', 'end': '3032', 'text': 'Such', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '152', 'text': 'BRENOCE , T N', 'TYPE': 'PATIENT'}
# {'start': '149', 'end': '173', 'text': 'SORBKOTESHUFF , CIOUSALE', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '165', 'text': 'PREHEPRIOR , NIENEMILEISELE', 'TYPE': 'PATIENT'}
# {'start': '175', 'end': '191', 'text': 'PAN , CALEOALE L', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '172', 'text': 'SELCFARST , NAORLY', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '166', 'text': 'YAM MELCGERLE', 'TYPE': 'PATIENT'}
# {'start': '258', 'end': '263', 'text': 'First', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '176', 'text': 'ED FRANCYIE KOTEVERGE', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '170', 'text': 'DUHETLAND , RIE', 'TYPE': 'PATIENT'}
# {'start': '174', 'end': '207', 'text': 'BELTTLANDJARREUTZCANTS , IEHETLEO', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '186', 'text': 'HULLEKOTE , AU', 'TYPE': 'PATIENT'}
# {'start': '196', 'end': '205', 'text': 'A , MIFER', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '176', 'text': 'SPIELBOBETREAU , EYRI', 'TYPE': 'PATIENT'}
# {'start': '189', 'end': '211', 'text': 'RIDLFRIELS , BRANTN M.', 'TYPE': 'PATIENT'}
# {'start': '174', 'end': '197', 'text': 'ROHEESCFOOKSKOTE , RUMA', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '195', 'text': 'TREAUTHORECHIRD , JUATHA', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '158', 'text': 'JESCSHUFFSUBE , CRIA S', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '174', 'text': 'FLICHFENK , VINNETA', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '169', 'text': 'ALEEB , LINEES', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '176', 'text': 'HALPENUSCLINKE , SEPH', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '174', 'text': 'KAYSFREIERMVEQUEDUHE , THAATA', 'TYPE': 'PATIENT'}
# {'start': '300', 'end': '329', 'text': 'KAYSFREIERMVEQUEDUHE , THAATA', 'TYPE': 'PATIENT'}
# {'start': '179', 'end': '200', 'text': 'SHUFFKOTE , TILDEZY R', 'TYPE': 'PATIENT'}
# {'start': '185', 'end': '208', 'text': 'AGNEAGURNE , ROLILLTA M', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '158', 'text': 'CHABEAYRE , SHELLTILI', 'TYPE': 'PATIENT'}
# {'start': '181', 'end': '196', 'text': 'NERA , DARUTHPA', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '172', 'text': 'XARAH RATIA SERVICE', 'TYPE': 'PATIENT'}
# {'start': '189', 'end': '205', 'text': 'NASEGREND , NINA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '176', 'text': 'KOTECLAUSE , NORLINE', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '174', 'text': 'WIERSTKOTEKAYSSEISE , STONRE', 'TYPE': 'PATIENT'}
# {'start': '300', 'end': '328', 'text': 'WIERSTKOTEKAYSSEISE , STONRE', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '173', 'text': 'PREHEPRIOR , NIENEMILEISELE', 'TYPE': 'PATIENT'}
# {'start': '299', 'end': '326', 'text': 'PREHEPRIOR , NIENEMILEISELE', 'TYPE': 'PATIENT'}
# {'start': '175', 'end': '187', 'text': 'TLING , ATLA', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '155', 'text': 'STOCK , LEAMA C', 'TYPE': 'PATIENT'}
# {'start': '304', 'end': '309', 'text': 'Stock', 'TYPE': 'PATIENT'}
# {'start': '165', 'end': '185', 'text': 'TROSVEINLAUNT , CIDY', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '171', 'text': 'THON MERI CINKGUAY', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '174', 'text': 'MOMSHAUNDCHIRD , JESSELBANGE', 'TYPE': 'PATIENT'}
# {'start': '300', 'end': '328', 'text': 'MOMSHAUNDCHIRD , JESSELBANGE', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '169', 'text': 'XARAH RATIA LOW', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '164', 'text': 'SLEM , YGA', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '155', 'text': 'GLYN , AEA', 'TYPE': 'PATIENT'}
# {'start': '281', 'end': '291', 'text': 'GLYN , AEA', 'TYPE': 'PATIENT'}
# {'start': '198', 'end': '223', 'text': 'OBEOBEGLOTZHAYTH , GILADI', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '178', 'text': 'BEATHEWIERSTJESC , JOWIL', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '152', 'text': 'SHUFF , RIREA P', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '175', 'text': 'RIASHWAN BERLNI THORE', 'TYPE': 'PATIENT'}
# {'start': '189', 'end': '217', 'text': 'RILLSCLANCEKOTE , TILITHIE X', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '176', 'text': 'JESCBULLSSUBE , SHALL', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '206', 'text': 'FEDDNOORT , RIKEREUGE LASSHA', 'TYPE': 'PATIENT'}
# {'start': '211', 'end': '236', 'text': 'PULESPANTSQUARCIN , NAA Q', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '154', 'text': 'KOTE , YGA', 'TYPE': 'PATIENT'}
# {'start': '280', 'end': '290', 'text': 'KOTE , YGA', 'TYPE': 'PATIENT'}
# {'start': '166', 'end': '192', 'text': 'KOTEGLYNFONG , AVANJINI L.', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '185', 'text': 'ZUKTRIG , ALVE', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '163', 'text': 'A , MIFER', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '179', 'text': 'ADEIDRE AUJERIELLE WHIPPLE', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '163', 'text': 'DOYLESHUFFBRUECK , REWILF', 'TYPE': 'PATIENT'}
# {'start': '167', 'end': '188', 'text': 'ASTWIERSTHUH , FAYJEA', 'TYPE': 'PATIENT'}
# {'start': '196', 'end': '232', 'text': 'FREIERMLINKENEIGHCAABLINFARST , ANEA', 'TYPE': 'PATIENT'}
# {'start': '181', 'end': '200', 'text': 'RHALTHEAGLE , LEELO', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '170', 'text': 'XARAH RATIA KOTE', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '170', 'text': 'AGACHBRAUCH , RENSIAANARC', 'TYPE': 'PATIENT'}
# {'start': '296', 'end': '321', 'text': 'AGACHBRAUCH , RENSIAANARC', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '159', 'text': 'GROKOTE , TRUCA', 'TYPE': 'PATIENT'}
# {'start': '285', 'end': '300', 'text': 'GROKOTE , TRUCA', 'TYPE': 'PATIENT'}
# {'start': '185', 'end': '208', 'text': 'CANTSNINSLOAARG , TRANI', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '172', 'text': 'WIERSTKERTH , RI', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '180', 'text': 'KOTEKEESECRANKBERF , ARY', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '169', 'text': 'CATHYS , LAEEN', 'TYPE': 'PATIENT'}
# {'start': '177', 'end': '197', 'text': 'WYNSHUFFSHUFF , RELL', 'TYPE': 'PATIENT'}
# {'start': '152', 'end': '163', 'text': 'SAPA , LEAY', 'TYPE': 'PATIENT'}
# {'start': '183', 'end': '204', 'text': 'BRESEUNG , ANGTARO T.', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '181', 'text': 'FREIERMLINKENEIGHCAABLINFARST , ANEA', 'TYPE': 'PATIENT'}
# {'start': '307', 'end': '343', 'text': 'FREIERMLINKENEIGHCAABLINFARST , ANEA', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '173', 'text': 'ARGMEASNEIGH , AVIS', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '185', 'text': 'ZISK , JACKENY', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '196', 'text': 'KOLLCOUNT , TORLEE', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '161', 'text': 'GUYNLUDZ , TALEO', 'TYPE': 'PATIENT'}
# {'start': '287', 'end': '303', 'text': 'GUYNLUDZ , TALEO', 'TYPE': 'PATIENT'}
# {'start': '135', 'end': '164', 'text': 'NEACEKOTEBREUNMUC , ZETTERA K', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '177', 'text': 'XIEACASS BETHCONRI PARA', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '191', 'text': 'NEIGHLOAD , OBYE Y', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '163', 'text': 'HUDES , ROLYNJEACA', 'TYPE': 'PATIENT'}
# {'start': '289', 'end': '307', 'text': 'HUDES , ROLYNJEACA', 'TYPE': 'PATIENT'}
# {'start': '168', 'end': '190', 'text': 'RHALTSLAKE , NICESUM D', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '157', 'text': 'RONGSAPTHORE , LIMIE', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '172', 'text': 'FREIERMDREPS , RI', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '164', 'text': 'CHURCUCHRHALT , LAQUE', 'TYPE': 'PATIENT'}
# {'start': '290', 'end': '311', 'text': 'CHURCUCHRHALT , LAQUE', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '164', 'text': 'GUYNLUDZ , STASIERDI', 'TYPE': 'PATIENT'}
# {'start': '290', 'end': '310', 'text': 'GUYNLUDZ , STASIERDI', 'TYPE': 'PATIENT'}
# {'start': '194', 'end': '205', 'text': 'GACH , DENA', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '187', 'text': 'ELKS , BRENNE L', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '154', 'text': 'BOORMSKI , NIKEE R', 'TYPE': 'PATIENT'}
# {'start': '468', 'end': '476', 'text': 'Boormski', 'TYPE': 'PATIENT'}
# {'start': '1779', 'end': '1793', 'text': 'Nikee Boormski', 'TYPE': 'PATIENT'}
# {'start': '2421', 'end': '2429', 'text': 'Boormski', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '176', 'text': 'SYSCO TAMARCE SHEGOING', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '173', 'text': 'DOUETSHUFF , RIELIE', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '160', 'text': 'TWINOORT , RUTIS', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '302', 'text': 'TWINOORT , RUTIS', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '179', 'text': 'TIKFREIERMMOONE , RIRAOCA', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '176', 'text': 'SQUARCDWILLFYFE , RAKA', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '154', 'text': 'SLEM , YGA', 'TYPE': 'PATIENT'}
# {'start': '280', 'end': '290', 'text': 'SLEM , YGA', 'TYPE': 'PATIENT'}
# {'start': '186', 'end': '202', 'text': 'ARUDES , ERMNI E', 'TYPE': 'PATIENT'}
# {'start': '183', 'end': '198', 'text': 'WOOL , HELENESS', 'TYPE': 'PATIENT'}
# {'start': '135', 'end': '154', 'text': 'BELBJESC , WITLASIE', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '191', 'text': 'FREIERMLINKENEIGHCAABLINFARST , ANEA', 'TYPE': 'PATIENT'}
# {'start': '151', 'end': '166', 'text': 'SAWTHORE , DIRI', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '170', 'text': 'CHIRDVOLN , IENA', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '181', 'text': 'PIERNHEAGLEFREIERM , NANIROL', 'TYPE': 'PATIENT'}
# {'start': '177', 'end': '194', 'text': 'DUOSSPALD , BRINI', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '149', 'text': 'SAP , A A', 'TYPE': 'PATIENT'}
# {'start': '174', 'end': '193', 'text': 'AGNEAGURNE , TOFRAN', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '193', 'text': 'JESCBULLSSUBE , SHALL', 'TYPE': 'PATIENT'}
# {'start': '144', 'end': '169', 'text': 'FYFEFREIERM , OLECARDRAND', 'TYPE': 'PATIENT'}
# {'start': '295', 'end': '320', 'text': 'FYFEFREIERM , OLECARDRAND', 'TYPE': 'PATIENT'}
# {'start': '189', 'end': '204', 'text': 'KAYSKUDZ , NARO', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '202', 'text': 'STREUSPERBREEF , HIREENGLEN E', 'TYPE': 'PATIENT'}
# {'start': '472', 'end': '486', 'text': 'Streusperbreef', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '183', 'text': 'XIEACASS BETHCONRI SURFACE', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '210', 'text': 'DOUETNOUNBREUNKOLL , STENRESLYSE', 'TYPE': 'PATIENT'}
# {'start': '158', 'end': '180', 'text': 'SWANKEGIERNILL , LAJAC', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '163', 'text': 'A , OLY', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '185', 'text': 'KOTEBELBBAINESGIERNTIPPS , FRANCARLNAKA', 'TYPE': 'PATIENT'}
# {'start': '311', 'end': '350', 'text': 'KOTEBELBBAINESGIERNTIPPS , FRANCARLNAKA', 'TYPE': 'PATIENT'}
# {'start': '221', 'end': '244', 'text': 'CHAFFKAULLTAUA , ANDARO', 'TYPE': 'PATIENT'}
# {'start': '2372', 'end': '2393', 'text': 'Andaro Chaffkaulltaua', 'TYPE': 'PATIENT'}
# {'start': '2379', 'end': '2393', 'text': 'Chaffkaulltaua', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'COUNTCHESNE , LASHA', 'TYPE': 'PATIENT'}
# {'start': '183', 'end': '207', 'text': 'FYFEFREIERMSKOC , THI D.', 'TYPE': 'PATIENT'}
# {'start': '174', 'end': '193', 'text': 'CRASSBELBKOTE , NEE', 'TYPE': 'PATIENT'}
# {'start': '158', 'end': '167', 'text': 'A , MIFER', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '156', 'text': 'KOTE , YGA', 'TYPE': 'PATIENT'}
# {'start': '282', 'end': '292', 'text': 'KOTE , YGA', 'TYPE': 'PATIENT'}
# {'start': '179', 'end': '194', 'text': 'WARESIN , SAGAY', 'TYPE': 'PATIENT'}
# {'start': '168', 'end': '183', 'text': 'GROKOTE , TRUCA', 'TYPE': 'PATIENT'}
# {'start': '219', 'end': '233', 'text': 'KAYSPER , TANO', 'TYPE': 'PATIENT'}
# {'start': '148', 'end': '166', 'text': 'ZINESMAN , NIENAMA', 'TYPE': 'PATIENT'}
# {'start': '292', 'end': '310', 'text': 'ZINESMAN , NIENAMA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'WURTH , BENSTEFFROB', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '161', 'text': 'KORCCEDEBREUTZ , NA R', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '163', 'text': 'KOTEKOTE , AGUYNYLEOTA B', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '185', 'text': 'POPPE , AA A.', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '187', 'text': 'STERPMOONE , NY', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '171', 'text': 'VEANSAP , CINDO', 'TYPE': 'PATIENT'}
# {'start': '200', 'end': '208', 'text': 'Breseung', 'TYPE': 'PATIENT'}
# {'start': '2060', 'end': '2068', 'text': 'Breseung', 'TYPE': 'PATIENT'}
# {'start': '2581', 'end': '2589', 'text': 'Breseung', 'TYPE': 'PATIENT'}
# {'start': '3512', 'end': '3520', 'text': 'Breseung', 'TYPE': 'PATIENT'}
# {'start': '195', 'end': '213', 'text': 'OBESAGE , MAXNA J.', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '186', 'text': 'FREIERMFETHBREUN , HILDERINEMI', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '166', 'text': 'A , MIFER', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '174', 'text': 'THON MERI CINKGUAY', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '180', 'text': 'ZEISRHALTPROT , QUETSHA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '166', 'text': 'A , WALINA', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '151', 'text': 'CHIRD , CARA', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '178', 'text': 'FARSTCLOZ , RICKNARYN', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '166', 'text': 'YAW , TAO', 'TYPE': 'PATIENT'}
# {'start': '169', 'end': '188', 'text': 'RHALTJESC , PAUSALA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '171', 'text': 'STERPMOONE , NY', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '174', 'text': 'SMANTVERGE , TAWNEN', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '181', 'text': 'RHALTA , XANNELOME NINERA', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '203', 'text': 'SCHOELLSULLKOTEFONG , DAWNNA T', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '192', 'text': 'CRASSBELBKOTE , NEE', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '212', 'text': 'LIKFREIERMKOTELEEBBREUTZ , LYNA N.', 'TYPE': 'PATIENT'}
# {'start': '1101', 'end': '1125', 'text': 'Likfreiermkoteleebbreutz', 'TYPE': 'PATIENT'}
# {'start': '158', 'end': '167', 'text': 'A , MIFER', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'RHALTSAP , KANDDESS', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '168', 'text': 'OBESELLEDE , XUANSTAR', 'TYPE': 'PATIENT'}
# {'start': '294', 'end': '315', 'text': 'OBESELLEDE , XUANSTAR', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '159', 'text': 'FYFEVAIA , LORERINDIL', 'TYPE': 'PATIENT'}
# {'start': '184', 'end': '207', 'text': 'CHIRDBAWN , CETENEKIRON', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '167', 'text': 'GACH , WADE', 'TYPE': 'PATIENT'}
# {'start': '167', 'end': '189', 'text': 'GELTNIQUE , TITRAMSILV', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '196', 'text': 'TIKFREIERMMOONE , RIRAOCA', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '177', 'text': 'TAWADE HOUGHTZUKSMUKES', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '165', 'text': 'OBEOBEGLOTZHAYTH , GILADI', 'TYPE': 'PATIENT'}
# {'start': '337', 'end': '346', 'text': 'Trickdene', 'TYPE': 'PATIENT'}
# {'start': '337', 'end': '346', 'text': 'Trickdene', 'TYPE': 'PATIENT'}
# {'start': '272', 'end': '279', 'text': 'Grokote', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '179', 'text': 'VETTEHOLOH RI JEFFEMELC', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '174', 'text': 'THON MERI CINKGUAY', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '178', 'text': 'BOORMCHIRDTIK , SEYGRA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '166', 'text': 'RONG , ARV', 'TYPE': 'PATIENT'}
# {'start': '177', 'end': '190', 'text': 'FYFELAT , LEN', 'TYPE': 'PATIENT'}
# {'start': '191', 'end': '208', 'text': 'FREIERMDREPS , RI', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '173', 'text': 'SHUFFJESC , NANORA', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '169', 'text': 'BOORMMAINESGLOMBEUCH , JAYTO T', 'TYPE': 'PATIENT'}
# {'start': '158', 'end': '171', 'text': 'DALEIS , NASU', 'TYPE': 'PATIENT'}
# {'start': '149', 'end': '164', 'text': 'ELKS , BRENNE L', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '163', 'text': 'KOTEMICLIFE , LYNRINU C', 'TYPE': 'PATIENT'}
# {'start': '184', 'end': '207', 'text': 'CHIRDBAWN , CETENEKIRON', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '169', 'text': 'LOAD , IEFAU', 'TYPE': 'PATIENT'}
# {'start': '176', 'end': '198', 'text': 'NATHEGAY , SHAIMAUS S.', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '160', 'text': 'PUZPAE , A RATALECA K', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '178', 'text': 'SCHOELLSULLKOTEFONG , MAUSTINIE', 'TYPE': 'PATIENT'}
# {'start': '304', 'end': '335', 'text': 'SCHOELLSULLKOTEFONG , MAUSTINIE', 'TYPE': 'PATIENT'}
# {'start': '181', 'end': '203', 'text': 'CHEAMPBUR , STEENRA R.', 'TYPE': 'PATIENT'}
# {'start': '165', 'end': '181', 'text': 'WIERSTKERTH , RI', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '168', 'text': 'SWANKEGIERNILL , LAJAC', 'TYPE': 'PATIENT'}
# {'start': '294', 'end': '316', 'text': 'SWANKEGIERNILL , LAJAC', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '177', 'text': 'SEINGIERN , LYNNYRIN', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'GNUSTRICK , MINCIEN', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '172', 'text': 'KOORSKOTE , RETCO', 'TYPE': 'PATIENT'}
# {'start': '143', 'end': '160', 'text': 'JESCFYFE , QUEL T', 'TYPE': 'PATIENT'}
# {'start': '186', 'end': '211', 'text': 'KOTEBITZWEERTS , LIXYNA N', 'TYPE': 'PATIENT'}
# {'start': '148', 'end': '168', 'text': 'TITCHECHIRD , EMDROW', 'TYPE': 'PATIENT'}
# {'start': '380', 'end': '397', 'text': 'Blood Titchechird', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '204', 'text': 'LUDZHAYTHTONERUDES , MASRA', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '196', 'text': 'FEDDNOORT , RIKEREUGE L', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '165', 'text': 'ROUCHEDUHETLAND , RA', 'TYPE': 'PATIENT'}
# {'start': '291', 'end': '311', 'text': 'ROUCHEDUHETLAND , RA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '172', 'text': 'ASHA KA BEALYARB', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '158', 'text': 'RHALT , CAYO', 'TYPE': 'PATIENT'}
# {'start': '284', 'end': '296', 'text': 'RHALT , CAYO', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '164', 'text': 'FREIERMLEEB , USNA', 'TYPE': 'PATIENT'}
# {'start': '290', 'end': '308', 'text': 'FREIERMLEEB , USNA', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '190', 'text': 'LARDES , ANIECA S.', 'TYPE': 'PATIENT'}
# {'start': '214', 'end': '218', 'text': 'SINT', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '181', 'text': 'BEATHEWIERSTJESC , JOWIL', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '175', 'text': 'MOFLEKERTH , JOSPRYL', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '194', 'text': 'KULRINNE , RYYELEGE N', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '156', 'text': 'FREIERMPRATL , NI L', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '180', 'text': 'YAM RAGAYME EGLERUDESKOTE', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '166', 'text': 'A , WALINA', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '175', 'text': 'TYNNEVENOORT , ALT', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '170', 'text': 'ZUKTRIG , ALVE', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '169', 'text': 'ININE CIAI OBE', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'FLICHFENK , VINNETA', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '178', 'text': 'CHAFFBITZ , TESSMONDMARV', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '174', 'text': 'BAINFREIERM , KYLAO', 'TYPE': 'PATIENT'}
# {'start': '201', 'end': '218', 'text': 'HAUTHFREDE , MEND', 'TYPE': 'PATIENT'}
# {'start': '153', 'end': '181', 'text': 'TISCHELLE ERNETTE BREUNSTERP', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '170', 'text': 'ASHA KA BEALYARB', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '178', 'text': 'RIASHWAN BERLNI VALLEY', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '182', 'text': 'AKOTE , NAO', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '160', 'text': 'LINKE , JAQUEY', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '300', 'text': 'LINKE , JAQUEY', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '168', 'text': 'LAFAR SCREEN', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'RIASHWAN BERLNI LOW', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '169', 'text': 'JESC , TADRO', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '188', 'text': 'TRUSKERTH , NA E', 'TYPE': 'PATIENT'}
# {'start': '205', 'end': '222', 'text': 'PREHERO , MARY R.', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '182', 'text': 'KOTESCHOELL , GEORGMACLAIRE', 'TYPE': 'PATIENT'}
# {'start': '175', 'end': '185', 'text': 'SLEM , YGA', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '171', 'text': 'DREISSNEIGH , ENE', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '162', 'text': 'CIENNE , GUTAOI', 'TYPE': 'PATIENT'}
# {'start': '288', 'end': '303', 'text': 'CIENNE , GUTAOI', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '160', 'text': 'ALNTITCHE , JEA', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '301', 'text': 'ALNTITCHE , JEA', 'TYPE': 'PATIENT'}
# {'start': '181', 'end': '200', 'text': 'ROBIDEPREHE , NISAU', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '151', 'text': 'AYLES , LINA C', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '192', 'text': 'XIEACASS BETHCONRI MANDESDUHECASHUFF', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '173', 'text': 'BOORMDRUDD , ZIERA', 'TYPE': 'PATIENT'}
# {'start': '172', 'end': '202', 'text': 'FREIERMFETHBREUN , HILDERINEMI', 'TYPE': 'PATIENT'}
# {'start': '183', 'end': '197', 'text': 'RALNMIENT , DY', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '162', 'text': 'AUSSTONGE , LILU', 'TYPE': 'PATIENT'}
# {'start': '288', 'end': '304', 'text': 'AUSSTONGE , LILU', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '196', 'text': 'STERPA , BURMCORDE', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '183', 'text': 'SLENTPEASEBUMPS , LISSSOND', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '161', 'text': 'JESCWIERST , MA', 'TYPE': 'PATIENT'}
# {'start': '287', 'end': '302', 'text': 'JESCWIERST , MA', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '177', 'text': 'GUYNLUDZ , STASIERDI', 'TYPE': 'PATIENT'}
# {'start': '246', 'end': '262', 'text': 'AUSSTONGE , LILU', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '176', 'text': 'JESCBULLSSUBE , SHALL', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '175', 'text': 'ROSULETLAND , RITO', 'TYPE': 'PATIENT'}
# {'start': '170', 'end': '184', 'text': 'HULLEKOTE , AU', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '180', 'text': 'BEATHEWIERSTJESC , JOWIL', 'TYPE': 'PATIENT'}
# {'start': '147', 'end': '165', 'text': 'STREUJILL , NACYND', 'TYPE': 'PATIENT'}
# {'start': '291', 'end': '309', 'text': 'STREUJILL , NACYND', 'TYPE': 'PATIENT'}
# {'start': '173', 'end': '194', 'text': 'BLINTONE , NATADELMJE', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '178', 'text': 'SOURS , NANONIFF ELLMI', 'TYPE': 'PATIENT'}
# {'start': '137', 'end': '158', 'text': 'TALCSILBE , RARIETI C', 'TYPE': 'PATIENT'}
# {'start': '2135', 'end': '2144', 'text': 'Talcsilbe', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '160', 'text': 'KATESJESC , RAI', 'TYPE': 'PATIENT'}
# {'start': '286', 'end': '301', 'text': 'KATESJESC , RAI', 'TYPE': 'PATIENT'}
# {'start': '139', 'end': '153', 'text': 'GINSLENT , A L', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '166', 'text': 'ININE JONES', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '159', 'text': 'SKI , YCHEROS', 'TYPE': 'PATIENT'}
# {'start': '285', 'end': '298', 'text': 'SKI , YCHEROS', 'TYPE': 'PATIENT'}
# {'start': '176', 'end': '187', 'text': 'FALC , COLL', 'TYPE': 'PATIENT'}
# {'start': '170', 'end': '192', 'text': 'SWANKEGIERNILL , LAJAC', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '168', 'text': 'LOAN , LYKEY', 'TYPE': 'PATIENT'}
# {'start': '140', 'end': '153', 'text': 'CHIY , MADO A', 'TYPE': 'PATIENT'}
# {'start': '188', 'end': '206', 'text': 'LAUNTTRISSA , THAA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '172', 'text': 'KOTEA , TORTHEOA', 'TYPE': 'PATIENT'}
# {'start': '221', 'end': '234', 'text': 'Seielspaldsna', 'TYPE': 'PATIENT'}
# {'start': '561', 'end': '574', 'text': 'Seielspaldsna', 'TYPE': 'PATIENT'}
# {'start': '1572', 'end': '1585', 'text': 'Seielspaldsna', 'TYPE': 'PATIENT'}
# {'start': '3504', 'end': '3517', 'text': 'Seielspaldsna', 'TYPE': 'PATIENT'}
# {'start': '176', 'end': '192', 'text': 'STENOBE , LANDEM', 'TYPE': 'PATIENT'}
# {'start': '192', 'end': '206', 'text': 'Nuscsmantpiern', 'TYPE': 'PATIENT'}
# {'start': '1611', 'end': '1625', 'text': 'Nuscsmantpiern', 'TYPE': 'PATIENT'}
# {'start': '2045', 'end': '2059', 'text': 'Nuscsmantpiern', 'TYPE': 'PATIENT'}
# {'start': '2839', 'end': '2853', 'text': 'Nuscsmantpiern', 'TYPE': 'PATIENT'}
# {'start': '193', 'end': '220', 'text': 'SOSTRE , MADDLENEFRANNIK P.', 'TYPE': 'PATIENT'}
# {'start': '165', 'end': '179', 'text': 'CHAFFBITZ , LI', 'TYPE': 'PATIENT'}
# {'start': '138', 'end': '165', 'text': 'JESCBLAGLEEBHAWNJO , NICK R', 'TYPE': 'PATIENT'}
# {'start': '186', 'end': '207', 'text': 'SLEMKOLL , TODLA DAIS', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '177', 'text': 'ELKSFALCBAINKIH , ON', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '162', 'text': 'LEEBSHUFFBREUN , CINTDRA I', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '167', 'text': 'SLEM , YGA', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '163', 'text': 'FREIERMDREPS , RI', 'TYPE': 'PATIENT'}
# {'start': '289', 'end': '306', 'text': 'FREIERMDREPS , RI', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '163', 'text': 'JESCPING , SEYMALI', 'TYPE': 'PATIENT'}
# {'start': '289', 'end': '307', 'text': 'JESCPING , SEYMALI', 'TYPE': 'PATIENT'}
# {'start': '168', 'end': '186', 'text': 'LINKECLOZ , RYJOTI', 'TYPE': 'PATIENT'}
# {'start': '170', 'end': '189', 'text': 'CRASSBELBKOTE , NEE', 'TYPE': 'PATIENT'}
# {'start': '177', 'end': '193', 'text': 'PER , ALEODESSTA', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '177', 'text': 'GLOTZASRHALT , SHIRLH', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '175', 'text': 'FRIEDVUILLE , GANGE', 'TYPE': 'PATIENT'}
# {'start': '154', 'end': '172', 'text': 'DARLSTELLPAL CHINA', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '166', 'text': 'BETLA CHECK', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '174', 'text': 'KOORSKOTE , RETCO', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '176', 'text': 'SMANTVERGE , TAWNEN', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '178', 'text': 'SWANKEGIERNILL , LAJAC', 'TYPE': 'PATIENT'}
# {'start': '192', 'end': '206', 'text': 'OBEFYFE , TREE', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '170', 'text': 'GUILDSELC , TAT', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '197', 'text': 'CLOZLARDAFREIERM , IEDEARC', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '186', 'text': 'SCOSTGACMARV , HELAVEHARBRASTY', 'TYPE': 'PATIENT'}
# {'start': '190', 'end': '217', 'text': 'ZUKMAVLARDES , CINEQUAMEAAA', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '176', 'text': 'FEDDNOORT , RIKEREUGE', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '180', 'text': 'SHUFFBELBBREUN , LYSSESG', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '196', 'text': 'ROSULETLAND , RITO', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '173', 'text': 'SYSCO TAMARCE PARA', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '164', 'text': 'ROSULETLAND , RITO', 'TYPE': 'PATIENT'}
# {'start': '290', 'end': '308', 'text': 'ROSULETLAND , RITO', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '174', 'text': 'JUARISY DUHESMITRE', 'TYPE': 'PATIENT'}
# {'start': '182', 'end': '205', 'text': 'ZEISRHALTPROT , QUETSHA', 'TYPE': 'PATIENT'}
# {'start': '171', 'end': '185', 'text': 'HEMPWIERST , E', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '166', 'text': 'DRINBLIN , MICYRSTNAE', 'TYPE': 'PATIENT'}
# {'start': '292', 'end': '313', 'text': 'DRINBLIN , MICYRSTNAE', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '173', 'text': 'SAPBAIN , HAITAI', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '185', 'text': 'CUCHSPARDCAMPMOTTELAMN , LARIN', 'TYPE': 'PATIENT'}
# {'start': '186', 'end': '206', 'text': 'UPHCAUGHBREUN , TAVO', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '171', 'text': 'FILLE , ETOKAITL', 'TYPE': 'PATIENT'}
# {'start': '722', 'end': '727', 'text': 'Fille', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '175', 'text': 'REKEBELBLILLE , WALD', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '174', 'text': 'RHALTHEAGLE , LEELO', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '169', 'text': 'ZEISSHUFFGACH , BETHBRA', 'TYPE': 'PATIENT'}
# {'start': '295', 'end': '318', 'text': 'ZEISSHUFFGACH , BETHBRA', 'TYPE': 'PATIENT'}
# {'start': '208', 'end': '228', 'text': 'TROSVEINLAUNT , CIDY', 'TYPE': 'PATIENT'}
# {'start': '182', 'end': '208', 'text': 'GOINGRATHEBREUN , MARLRAND', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '178', 'text': 'ADEIDRE AUJERIELLE LEWY', 'TYPE': 'PATIENT'}
# {'start': '183', 'end': '200', 'text': 'LIEPKOLL , ZOMARG', 'TYPE': 'PATIENT'}
# {'start': '146', 'end': '181', 'text': 'SHUFFHICKEJESCSKOCBLEAKWORCE , RIDO', 'TYPE': 'PATIENT'}
# {'start': '307', 'end': '342', 'text': 'SHUFFHICKEJESCSKOCBLEAKWORCE , RIDO', 'TYPE': 'PATIENT'}
# {'start': '157', 'end': '172', 'text': 'STERPMOONE , NY', 'TYPE': 'PATIENT'}
# {'start': '145', 'end': '158', 'text': 'JEMSKOP , COT', 'TYPE': 'PATIENT'}
# {'start': '284', 'end': '297', 'text': 'JEMSKOP , COT', 'TYPE': 'PATIENT'}
# {'start': '219', 'end': '244', 'text': 'DOUETKOTEIS , TAMELISSEAE', 'TYPE': 'PATIENT'}
# {'start': '155', 'end': '177', 'text': 'NOREDCHIRD , MICHEFRAN', 'TYPE': 'PATIENT'}
# {'start': '178', 'end': '210', 'text': 'LEUBGACHSHICROOBENCHCHIRD , DYRO', 'TYPE': 'PATIENT'}
# {'start': '136', 'end': '155', 'text': 'FLICHFENK , VINNETA', 'TYPE': 'PATIENT'}
# {'start': '187', 'end': '205', 'text': 'CHAUFFEBUIE , GUST', 'TYPE': 'PATIENT'}
# {'start': '206', 'end': '222', 'text': 'GABEFREIERM , DE', 'TYPE': 'PATIENT'}
# {'start': '900', 'end': '920', 'text': 'Let Dawny Nellthrelk', 'TYPE': 'PATIENT'}
# {'start': '156', 'end': '177', 'text': 'DEALBISSAXT , ALFSHAE', 'TYPE': 'PATIENT'}
# {'start': '201', 'end': '214', 'text': 'AGREND , RA A', 'TYPE': 'PATIENT'}
# {'start': '174', 'end': '191', 'text': 'FYFEWIERST , MIER', 'TYPE': 'PATIENT'}
# {'start': '339', 'end': '357', 'text': 'Guynlordsmantdouet', 'TYPE': 'PATIENT'}
# {'start': '177', 'end': '194', 'text': 'MEEDBELB , LIND E', 'TYPE': 'PATIENT'}

# %%
findAllEntity(df_2006Test)
# Out:
# {'AGE', 'DATE', 'DOCTOR', 'HOSPITAL', 'ID', 'LOCATION', 'PATIENT', 'PHONE'}
